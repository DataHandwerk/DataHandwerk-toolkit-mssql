-- %%
SELECT  [RepoObject_guid]
      ,[SysObject_fullname]
      ,[sql_modules_json]
      ,[class]
      ,[is_group]
      ,[is_keyword]
      ,[is_whitespace]
      ,[normalized]
      ,[children]
  FROM [repo].[RepoObject_SqlModules_10_statement]
  WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.682
-- ...

-- %%
SELECT  [RepoObject_guid]
      ,[json_key]
      ,[SysObject_fullname]
      ,[RowNumber_per_Object]
      ,[class]
      ,[is_group]
      ,[is_keyword]
      ,[is_whitespace]
      ,[normalized]
      ,[children]
      ,[child0_class]
      ,[child0_is_group]
      ,[child0_is_keyword]
      ,[child0_is_whitespace]
      ,[child0_normalized]
      ,[child0_children]
      ,[child1_class]
      ,[child1_is_group]
      ,[child1_is_keyword]
      ,[child1_is_whitespace]
      ,[child1_normalized]
      ,[child1_children]
      ,[child2_class]
      ,[child2_is_group]
      ,[child2_is_keyword]
      ,[child2_is_whitespace]
      ,[child2_normalized]
      ,[child2_children]
      ,[child3_class]
      ,[child3_is_group]
      ,[child3_is_keyword]
      ,[child3_is_whitespace]
      ,[child3_normalized]
      ,[child3_children]
      ,[child4_class]
      ,[child4_is_group]
      ,[child4_is_keyword]
      ,[child4_is_whitespace]
      ,[child4_normalized]
      ,[child4_children]
  FROM [repo].[RepoObject_SqlModules_20_statement_children]
    WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (8 rows affected)
-- Total execution time: 00:00:01.662
-- ...

-- %%
SELECT  [RepoObject_guid]
      ,[SysObject_fullname]
      ,[class]
      ,[json_key]
      ,[RowNumber_per_Object]
      ,[name]
      ,[name_charindex_dot]
      ,[name_PreDot]
      ,[name_PostDot]
      ,[alias]
      ,[T1_identifier_alias]
      ,[lag_normalized_wo_nolock]
      ,[alias_QuoteName]
      ,[name_PreDot_QuoteName]
      ,[name_PostDot_QuoteName]
  FROM [repo].[RepoObject_SqlModules_44_from_Identifier_QuoteName]
    WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.558
-- <table><tr><th>RepoObject_guid</th><th>SysObject_fullname</th><th>class</th><th>json_key</th><th>RowNumber_per_Object</th><th>name</th><th>name_charindex_dot</th><th>name_PreDot</th><th>name_PostDot</th><th>alias</th><th>T1_identifier_alias</th><th>lag_normalized_wo_nolock</th><th>alias_QuoteName</th><th>name_PreDot_QuoteName</th><th>name_PostDot_QuoteName</th></tr><tr><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>[graph].[RepoObject_S]</td><td>Identifier</td><td>7</td><td>8</td><td>[repo].[RepoObject]</td><td>7</td><td>[repo]</td><td>[RepoObject]</td><td>NULL</td><td>NULL</td><td>NULL</td><td>NULL</td><td>[repo]</td><td>[RepoObject]</td></tr></table>

-- %%
SELECT [RepoObject_guid]
      ,[SysObject_fullname]
      ,[RepoObjectColumn_guid]
      ,[RepoObjectColumn_name]
      ,[source_RepoObject_guid]
      ,[source_SysObject_fullname]
      ,[source_RepoObjectColumn_guid]
      ,[source_RepoObjectColumn_name]
      ,[source_table_QuoteName]
      ,[source_column_QuoteName]
      ,[alias_QuoteName]
      ,[normalized]
  FROM [repo].[RepoObject_SqlModules_71_reference_ExpliciteTableAlias]
      WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.462
-- <table><tr><th>RepoObject_guid</th><th>SysObject_fullname</th><th>RepoObjectColumn_guid</th><th>RepoObjectColumn_name</th><th>source_RepoObject_guid</th><th>source_SysObject_fullname</th><th>source_RepoObjectColumn_guid</th><th>source_RepoObjectColumn_name</th><th>source_table_QuoteName</th><th>source_column_QuoteName</th><th>alias_QuoteName</th><th>normalized</th></tr></table>

-- %%
SELECT  [RepoObject_guid]
      ,[SysObject_fullname]
      ,[RepoObjectColumn_guid]
      ,[RepoObjectColumn_name]
      ,[source_RepoObject_guid]
      ,[source_SysObject_fullname]
      ,[source_RepoObjectColumn_guid]
      ,[source_RepoObjectColumn_name]
      ,[source_table_QuoteName]
      ,[source_column_QuoteName]
      ,[alias_QuoteName]
      ,[normalized]
  FROM [repo].[RepoObject_SqlModules_72_reference_NoTableAlias]
      WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.092
-- <table><tr><th>RepoObject_guid</th><th>SysObject_fullname</th><th>RepoObjectColumn_guid</th><th>RepoObjectColumn_name</th><th>source_RepoObject_guid</th><th>source_SysObject_fullname</th><th>source_RepoObjectColumn_guid</th><th>source_RepoObjectColumn_name</th><th>source_table_QuoteName</th><th>source_column_QuoteName</th><th>alias_QuoteName</th><th>normalized</th></tr><tr><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>[graph].[RepoObject_S]</td><td>aa9fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>RepoObject_guid</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>[repo].[RepoObject]</td><td>aff17926-9d61-eb11-84dc-a81e8446d5b0</td><td>RepoObject_guid</td><td>NULL</td><td>[RepoObject_guid]</td><td>[RepoObject_guid]</td><td>[RepoObject_guid]
-- ...

-- %%
SELECT TOP (1000) [RepoObject_guid]
      ,[SysObject_fullname]
      ,[RepoObjectColumn_guid]
      ,[RepoObjectColumn_name]
      ,[source_RepoObject_guid]
      ,[source_SysObject_fullname]
      ,[source_RepoObjectColumn_guid]
      ,[source_RepoObjectColumn_name]
      ,[source_table_QuoteName]
      ,[source_column_QuoteName]
      ,[alias_QuoteName]
      ,[normalized]
  FROM [repo].[RepoObject_SqlModules_79_reference_union]
    WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.320
-- <table><tr><th>RepoObject_guid</th><th>SysObject_fullname</th><th>RepoObjectColumn_guid</th><th>RepoObjectColumn_name</th><th>source_RepoObject_guid</th><th>source_SysObject_fullname</th><th>source_RepoObjectColumn_guid</th><th>source_RepoObjectColumn_name</th><th>source_table_QuoteName</th><th>source_column_QuoteName</th><th>alias_QuoteName</th><th>normalized</th></tr><tr><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>[graph].[RepoObject_S]</td><td>aa9fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>RepoObject_guid</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>[repo].[RepoObject]</td><td>aff17926-9d61-eb11-84dc-a81e8446d5b0</td><td>RepoObject_guid</td><td>NULL</td><td>[RepoObject_guid]</td><td>[RepoObject_guid]</td><td>[RepoObject_guid]
-- ...

-- %%
SELECT  [referencing_id]
      ,[referencing_minor_id]
      ,[referencing_node_id]
      ,[referenced_id]
      ,[referenced_minor_id]
      ,[referenced_node_id]
      ,[referencing_RepoObject_guid]
      ,[referencing_RepoObjectColumn_guid]
      ,[referenced_RepoObject_guid]
      ,[referenced_RepoObjectColumn_guid]
      ,[referencing_type]
      ,[referencing_schema_name]
      ,[referencing_entity_name]
      ,[referencing_column_name]
      ,[referenced_schema_name]
      ,[referenced_entity_name]
      ,[referenced_column_name]
      ,[referenced_type]
      ,[InformationSource]
      ,[is_computed]
      ,[definition]
      ,[is_referencing_object_equal_referenced_object]
      ,[is_referenced_object]
      , [SysObject_fullname]
  FROM [repo].[RepoObjectColumn_reference_SqlModules]
WHERE SysObject_fullname = '[graph].[RepoObject_S]'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.328
-- ...

-- %%
SELECT [index_guid]
      ,[index_column_id]
      ,[is_descending_key]
      ,[referenced_RepoObject_guid]
      ,[referenced_RepoObjectColumn_guid]
      ,[referencing_RepoObject_guid]
      ,[referencing_RepoObjectColumn_guid]
      ,[RowNumberInReferencing]
  FROM [repo].[IndexColumn_ReferencedReferencing_HasFullColumnsInReferencing]
  where referencing_RepoObject_guid = 'a89fcdb3-3265-eb11-84dd-a81e8446d5b0'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:04.823
-- <table><tr><th>index_guid</th><th>index_column_id</th><th>is_descending_key</th><th>referenced_RepoObject_guid</th><th>referenced_RepoObjectColumn_guid</th><th>referencing_RepoObject_guid</th><th>referencing_RepoObjectColumn_guid</th><th>RowNumberInReferencing</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>1</td><td>0</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>aff17926-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>aa9fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>1</td></tr></table>

-- %% [markdown]
-- das sieht OK aus. Ein referenced Index wird vererbt
-- Jetzt ein Test, ob das auch in der Persistierung enthalten ist:

-- %%
SELECT [index_guid]
      ,[index_column_id]
      ,[is_descending_key]
      ,[referenced_RepoObject_guid]
      ,[referenced_RepoObjectColumn_guid]
      ,[referencing_RepoObject_guid]
      ,[referencing_RepoObjectColumn_guid]
      ,[RowNumberInReferencing]
  FROM [repo].[IndexColumn_ReferencedReferencing_HasFullColumnsInReferencing_T]
  where referencing_RepoObject_guid = 'a89fcdb3-3265-eb11-84dd-a81e8446d5b0'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.139
-- <table><tr><th>index_guid</th><th>index_column_id</th><th>is_descending_key</th><th>referenced_RepoObject_guid</th><th>referenced_RepoObjectColumn_guid</th><th>referencing_RepoObject_guid</th><th>referencing_RepoObjectColumn_guid</th><th>RowNumberInReferencing</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>1</td><td>0</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>aff17926-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>aa9fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>1</td></tr></table>

-- %% [markdown]
-- ist auch OK, jetzt mal dort die guid auflösen

-- %%
SELECT T1.[index_guid]
      ,T1.[index_column_id]
      , roc1.RepoObject_fullname
      , roc1.RepoObjectColumn_name
      , roc2.RepoObject_fullname
      , roc2.RepoObjectColumn_name
      ,T1.[is_descending_key]
      ,T1.[referenced_RepoObject_guid]
      ,T1.[referenced_RepoObjectColumn_guid]
      ,T1.[referencing_RepoObject_guid]
      ,T1.[referencing_RepoObjectColumn_guid]
      ,T1.[RowNumberInReferencing]
  FROM [repo].[IndexColumn_ReferencedReferencing_HasFullColumnsInReferencing_T] T1
  inner join [repo].[RepoObjectColumn_gross] roc1
  on roc1.[RepoObjectColumn_guid] = T1.referenced_RepoObjectColumn_guid
  inner join [repo].[RepoObjectColumn_gross] roc2
  on roc2.[RepoObjectColumn_guid] = T1.referencing_RepoObjectColumn_guid

  where referencing_RepoObject_guid = 'a89fcdb3-3265-eb11-84dd-a81e8446d5b0'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.519
-- <table><tr><th>index_guid</th><th>index_column_id</th><th>RepoObject_fullname</th><th>RepoObjectColumn_name</th><th>RepoObject_fullname</th><th>RepoObjectColumn_name</th><th>is_descending_key</th><th>referenced_RepoObject_guid</th><th>referenced_RepoObjectColumn_guid</th><th>referencing_RepoObject_guid</th><th>referencing_RepoObjectColumn_guid</th><th>RowNumberInReferencing</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>1</td><td>[repo].[RepoObject]</td><td>RepoObject_guid</td><td>[graph].[RepoObject_S]</td><td>RepoObject_guid</td><td>0</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>aff17926-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>aa9fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>1</td></tr></table>

-- %% [markdown]
-- alles OK

-- %%
SELECT [source_index_guid]
      ,[source_index_type]
      ,[referenced_RepoObject_guid]
      ,[referencing_RepoObject_guid]
      ,[referenced_index_guid]
      ,[RowNumberInReferencing_Target]
      ,[RowNumberInReferencing]
      ,[referencing_IndexPatternColumnGuid]
  FROM [repo].[IndexReferencedReferencing_HasFullColumnsInReferencing]
    where referencing_RepoObject_guid = 'a89fcdb3-3265-eb11-84dd-a81e8446d5b0'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.656
-- <table><tr><th>source_index_guid</th><th>source_index_type</th><th>referenced_RepoObject_guid</th><th>referencing_RepoObject_guid</th><th>referenced_index_guid</th><th>RowNumberInReferencing_Target</th><th>RowNumberInReferencing</th><th>referencing_IndexPatternColumnGuid</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>1</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>NULL</td><td>NULL</td><td>1</td><td>AA9FCDB3-3265-EB11-84DD-A81E8446D5B0</td></tr></table>

-- %% [markdown]
-- Das ist NICHT OK, hier müsste der Index enthalten sein.
-- Also schauen wir in den Vorgänger

-- %%
SELECT  [source_index_guid]
      ,[source_index_type]
      ,[referenced_RepoObject_guid]
      ,[referencing_RepoObject_guid]
      ,[referenced_index_guid]
      ,[RowNumberInReferencing_Target]
  FROM [repo].[IndexReferencedReferencing]
    where referencing_RepoObject_guid = 'a89fcdb3-3265-eb11-84dd-a81e8446d5b0'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:01.751
-- <table><tr><th>source_index_guid</th><th>source_index_type</th><th>referenced_RepoObject_guid</th><th>referencing_RepoObject_guid</th><th>referenced_index_guid</th><th>RowNumberInReferencing_Target</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>1</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>NULL</td><td>NULL</td></tr><tr><td>ef8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>2</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>NULL</td><td>NULL</td></tr><tr><td>f18f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>2</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>a89fcdb3-3265-eb11-84dd-a81e8446d5b0</td><td>NULL</td><td>NULL</td></tr></table>

-- %% [markdown]
-- leer, hier ist also der Fehler

-- %%
SELECT  [index_guid]
      ,[parent_RepoObject_guid]
      ,[index_name]
      ,[index_type]
      ,[is_index_unique]
      ,[is_index_primary_key]
      ,[is_index_disabled]
      ,[IndexPatternColumnGuid]
      ,[referenced_index_guid]
      ,[is_index_real]
  FROM [repo].[Index_union]
  where
  [index_guid] = 'ed8f291c-9d61-eb11-84dc-a81e8446d5b0'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.753
-- <table><tr><th>index_guid</th><th>parent_RepoObject_guid</th><th>index_name</th><th>index_type</th><th>is_index_unique</th><th>is_index_primary_key</th><th>is_index_disabled</th><th>IndexPatternColumnGuid</th><th>referenced_index_guid</th><th>is_index_real</th></tr><tr><td>ed8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>eb8f291c-9d61-eb11-84dc-a81e8446d5b0</td><td>PK_RepoObject</td><td>1</td><td>1</td><td>1</td><td>0</td><td>AFF17926-9D61-EB11-84DC-A81E8446D5B0</td><td>NULL</td><td>1</td></tr></table>

-- %% [markdown]
-- Der Index fehlt schon in [repo].[Index_union]
-- Wie kann das sein?

-- %%
SELECT
       [ic].*
FROM
     [repo].[IndexColumn_ReferencedReferencing_HasFullColumnsInReferencing] AS ic
WHERE  NOT EXISTS
(
    SELECT
           1
    FROM
         [repo].[Index_union] AS [i]
    WHERE  [ic].[index_guid] = [i].[index_guid]
)
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:05.220
-- ...

-- %% [markdown]
-- Es fehlt wohl nur dieser eine Index!
-- Also noch einen Schritt zurück.

-- %%
/****** Script for SelectTopNRows command from SSMS  ******/
SELECT  [index_guid]
      ,[index_column_id]
      ,[is_descending_key]
      ,[RepoObjectColumn_guid]
      ,[parent_RepoObject_guid]
      ,[index_name]
      ,[parent_schema_name]
      ,[parent_SysObject_name]
      ,[SysObject_column_name]
      ,[SysObject_column_user_type_fullname]
      ,[is_index_unique]
      ,[is_index_primary_key]
      ,[is_index_real]
      ,[parent_SysObject_fullname]
  FROM [repo].[IndexColumn_union]AS ic
WHERE  NOT EXISTS
(
    SELECT
           1
    FROM
         [repo].[Index_union] AS [i]
    WHERE  [ic].[index_guid] = [i].[index_guid]
)
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:02.021
-- ...

-- %% [markdown]
-- Die virtuellen Indizies müssen konsistent sein, schauen wir uns die realen an:

-- %%
SELECT
       [index_guid]
     , [index_column_id]
     , [is_descending_key]
     , [RepoObjectColumn_guid]
     , [parent_RepoObject_guid]
     , [index_name]
     , [parent_schema_name]
     , [parent_SysObject_name]
     , [SysObject_column_name]
     , [SysObject_column_user_type_fullname]
     , [is_index_unique]
     , [is_index_primary_key]
     , [parent_SysObject_fullname]
     , [is_index_real]
     , [index_id]
FROM
     [repo_sys].[IndexColumn_real_unique] AS ic
WHERE  NOT EXISTS
(
    SELECT
           1
    FROM
         [repo_sys].[Index_real_unique] AS [i]
    WHERE  [ic].[index_guid] = [i].[index_guid]
)
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.753
-- ...

-- %%
--ALTER VIEW [repo_sys].[Index_real_unique]
--AS
----
SELECT [index_guid] = [ro_index].[RepoObject_guid]
 , [index_name] = [si].[name] COLLATE database_default
 , [si].[index_id]
 , [si].[is_unique] AS [is_index_unique]
 , [si].[is_primary_key] AS [is_index_primary_key]
 , [si].[is_unique_constraint] AS [is_index_unique_constraint]
 , [si].[is_disabled] AS [is_index_disabled]
 , [si].[type] AS [index_type]
 , [si].[type_desc] AS [index_type_desc]
 , [parent_RepoObject_guid] = [ro_parent].[RepoObject_guid]
 , [parent_schema_name] = [ro_parent].[SysObject_schema_name]
 , [parent_SysObject_name] = [ro_parent].[SysObject_name]
 , [parent_SysObject_fullname] = [ro_parent].[SysObject_fullname]
FROM sys_dwh.indexes AS si
LEFT JOIN repo.RepoObject AS ro_index
 ON ro_index.SysObject_name = si.name COLLATE database_default
  AND ro_index.SysObject_parent_object_id = si.object_id
LEFT JOIN repo.RepoObject AS ro_parent
 ON ro_parent.SysObject_id = si.object_id
WHERE [si].[is_unique] = 1
----This is the issue!!!
-- AND NOT [ro_index].[RepoObject_guid] IS NULL
-- Out:
-- (196 rows affected)
-- Total execution time: 00:00:00.137
-- ...

-- %% [markdown]
-- Einige Objekte fehlen also in repo.RepoObject?

-- %%
/****** Script for SelectTopNRows command from SSMS  ******/
SELECT [SysObject_id]
      ,[SysObject_schema_name]
      ,[SysObject_name]
      ,[SysObject_fullname]
      ,[SysObject_RepoObject_guid]
      ,[principal_id]
      ,[schema_id]
      ,[parent_object_id]
      ,[type]
      ,[type_desc]
      ,[create_date]
      ,[modify_date]
      ,[is_ms_shipped]
      ,[is_published]
      ,[is_schema_published]
      ,[temporal_type]
      ,[temporal_type_desc]
      ,[history_table_id]
      ,[max_column_id_used]
      ,[sql_modules_definition]
  FROM [repo_sys].[SysObject]
where 
[SysObject_RepoObject_guid] = 'ed8f291c-9d61-eb11-84dc-a81e8446d5b0'
or
[SysObject_RepoObject_guid] is null
order by [type]
, [SysObject_fullname]
-- Out:
-- (9 rows affected)
-- Total execution time: 00:00:00.179
-- ...

-- %% [markdown]
-- Diese Tabelle ist OK, es gibt den PK also in RepoObject
--
-- Die weitere Analyse zeigt, es gibt einen falschen [SysObject_parent_object_id] in repo.RepoObject: 146099561
-- Fehler in Step 210 von [repo].[usp_sync_guid_RepoObject]
-- dort war die Aktualisierung auskommentiert
